# %%
import re
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
text = "I am studying Natural Language Processing, and it's really interesting!"
print(text)
# Out:
# I am studying Natural Language Processing, and it's really interesting!

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['I', 'am', 'studying', 'Natural', 'Language', 'Processing', ',', 'and', 'it', "'s", 'really', 'interesting', '!']

# %%
#Removing all punctutaion marks
tokens_regex = re.findall(r'\b\w+\b', text)
print(tokens_regex)
# Out:
# ['I', 'am', 'studying', 'Natural', 'Language', 'Processing', 'and', 'it', 's', 'really', 'interesting']

# %%
#Removal of Stopwords
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_tokens = [word for word in tokens_regex if word.lower() not in stop_words]

print(filtered_tokens)
# Out:
# ['studying', 'Natural', 'Language', 'Processing', 'really', 'interesting']

# %%
#Reducing words to root form
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_tokens]

print(stemmed_words)
# Out:
# ['studi', 'natur', 'languag', 'process', 'realli', 'interest']

# %%
#Converts words to dictionary-meaningful base form
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print(lemmatized_words)
# Out:
# ['studying', 'Natural', 'Language', 'Processing', 'really', 'interesting']

# %%
lowercase_words = [word.lower() for word in lemmatized_words]
print(lowercase_words)
# Out:
# ['studying', 'natural', 'language', 'processing', 'really', 'interesting']

# %%
text_with_numbers = "NLP is useful in 2024 and beyond"

clean_text = re.sub(r'\d+', '', text_with_numbers)
print(clean_text)
# Out:
# NLP is useful in  and beyond

# %%
final_text = " ".join(lowercase_words)
print(final_text)
# Out:
# studying natural language processing really interesting
